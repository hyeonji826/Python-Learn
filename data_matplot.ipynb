# %% [markdown]
# <a href="https://colab.research.google.com/github/hyeonji826/Python-Learn/blob/main/data_matplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 파이썬으로 데이터 시각화
# - 데이터 시각화란, 데이터를 그래프를 통해서 시각적으로
# 정보의 흐름이나 경향성을 파악하기 쉽게 만들어주는 것으로
# 의미한다.
# - 이러한 데이터 시각화에 필수로 쓰이는 것으로 알려진 라이브러리는 3가지로
#     1. matplotlib
#     2. pandas
#     3. seaborn
#     등이 있다.

# %%
# 필요한 라이브러리 설치(코랩에서는 기본적으로 설치되어있음.)
# !pip install matplotlib pandas seaborn

# %% [markdown]
# ## 기본 그래프 그리기
# ### 그래프의 종류
# - 선 그래프 : 시간에 따른 변화나 연속적인 데이터를 표현할 때 사용한다.
# - 막대 그래프 : 범주별 비교나 빈도, 양을 비교할 때 효과적이다.
# - 산점도(scatter point): 두 변수 간의 관계를 보여줄 때 유용하다.
# - 파이 차트(pie chart) : 전체에 대한 부분의 비율을 표현할 때 사용
# - 히스토그램(histogram) : 연속적인 데이터의 분포를 나타낼 때 사용

# %% [markdown]
# ### 선 그래프
# ''' python
# plt.ploy(x,y)
# '''
# - 위 코드로 선 그래프를 그릴 수 있다.

# %%
# matplotlib과 numpy 라이브러리 임포트
import matplotlib.pyplot as plt
import numpy as np

# %%
# x축 데이터 생성(0부터10까지 100갸의 균등한 간격의 점 생성)
x = np.linspace(0,10,100)
print(x)

# y축 데이터 생성(sin함수 적용)
y =np.sin(x)
print(y)
# Out:
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
# ...

# %%
# 그래프 그리기
plt.plot(x,y)

# 그래프 상단에 타이틀 정보 입력(기본 한글 깨짐)
plt.title("Title")

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4,5]
y=[10,20,25,30,40]

plt.plot(x,y,marker='0',linestyle='-',color='b',label="데이터")
plt.xlabel("X축")
plt.ylabel("Y축")
plt.title("Basic line plot")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 40]

plt.plot(x, y, marker='o', linestyle='-', color='b', label="데이터")
plt.xlabel("X")
plt.ylabel("Y")
plt.title("기본 선 그래프")
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.random.randn(100)		# 정규 분포를 따르는 1000개의 난수 생성
plt.hist(data, bins=30, color='skyblue', edgecolor='black')
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("histogram practice")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# 랜덤 데이터 생성
np.random.seed(42)
data = np.random.randn(1000)

# 히스토그램과 커널 밀도 그래프(KDE)
sns.histplot(data, kde=True, color="blue")
plt.title("Seaborn histogram practice")
plt.show()

# %% [markdown]
# ### 막대 그래프
# barplot
# - 범주형 데이터를 시각화하는 데 효과적인 방법이다.
# - 각 범주(catrgory)는 높이나 길이가 데이터 값에 비례하는 막대로 표현된다.
#
# #### 그래프의 특징
# - 데이터 비교 : 서로 다른 범주 간에 수량이나 크기, 길이 등을 쉽게 비교할 수 있다.
# - 간단한 해석 : 직관적이어서 쉽게 이해할 수 있다.
# - 다양한 형태 : 세로 막대가 기본이지만 가로 막대나 누적 막대 등 다양한 형태로 표현될 수 있다.
#
# '''python
# df = pd.DataFrame(data)
# plt.bar(df['x축'],df['y축'])
# '''
#
# 위 코드로 막대 그래프를 그릴 수 있다.

# %%
# 데이터 프레임을 생성하기 위한 pandas 임포트
import pandas as pd

# %%
# 더미 데이터 생성
# 각 value의 리스트 길이는 모두 동일해야 한다.
data ={
    'fruit':['apple','banana','orange'],
    'sell_amount':[45,32,50]
}
# 데이터프레임으로 변환
df=pd.DataFrame(data)

# %%
# 막대 그래프로 시각화
# 첫번째 인수는 x축에 배치, 두번째 인수는 y축에 배치
plt.bar(df['fruit'],df['sell_amount'])

# 시각화
plt.show()

# %% [markdown]
# ### Seaborn을 활용한 고급 시각화
# - seaborn은 통계적 그래프를 쉽게 그릴 수 있는 라이브러리다.
# ```python
# import seaborn as sns
# ```
#
# # 예시 데이터셋 로드
# ```
# tips = sns.load_dataset("tips")
# sns.scatterplot(x="total_bil",y="tip",data=tips)
# plt.show()
# ```

# %%
# seaborn 라이브버리 임포트
import seaborn as sns

# 예제 데이터셋 로드
tips = sns.load_dataset("tips")
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# 산점도 그리기
# x축은 총 계산서
# y축은 팁
# 두 변수의 관계를 산점도로 표현한다.
sns.scatterplot(x="total_bill", y="tip", data=tips)
plt.show()
